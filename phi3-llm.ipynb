# %% [markdown]
# # Geneate a prompt from Phi3 mini using GPU

# %%
# !python3 -m pip install --upgrade h5py
# !pip install transformers==4.28.0
#!pip install peft
# !pip install --upgrade accelerate
# !pip install -q --upgrade accelerate einops xformers
# !pip install --upgrade transformers
# !nvidia-smi
# Out:
# Tue Nov  5 04:52:47 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8             12W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ###  If the output shows that there is no GPU found, then change the accelator setting from the Kaggle setting above and change it to any of the GPU accelators.

# %%
# LLM using Phi3 

from transformers import AutoModelForCausalLM, AutoTokenizer

# Load model and tokenizer using Phi3
model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4K-instruct",
    device_map = "cuda",          
    torch_dtype = "auto",
    trust_remote_code = True,
)

tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4K-instruct")
# Out:
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-4K-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-4K-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/16.5k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## Here is the code above but with using pipeline instead:

# %%
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer

# Ensure model and tokenizer load successfully
model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4K-instruct",
    device_map="auto",  # Auto will pick CUDA if available, CPU otherwise
    torch_dtype="auto",
    trust_remote_code=True,
)

tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4K-instruct")

# Create text generation pipeline
generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
    max_new_tokens=500,
    do_sample=False
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# The prompt 
# Check output structure
output = generator("Who is the next president of the US")
print(output)
# Out:
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# [{'generated_text': "?\n\n## Answer:As of my last update in April 2023, Joe Biden is the current President of the United States. He was inaugurated as the 46th president on January 20, 2021, after winning the 2020 presidential election against incumbent Donald Trump. Biden, a member of the Democratic Party, previously served as the 47th Vice President of the United States from 2009 to 2017 under President Barack Obama. His presidency is marked by efforts to address the COVID-19 pandemic, economic recovery, and climate change, among other issues. It's important to note that political landscapes can change, and future elections could potentially alter the presidency."}]
